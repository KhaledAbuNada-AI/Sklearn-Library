# %%
import random
import math
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# %%
# make data

random.seed(123)

def getData(N):
    
    x,y = [],[]
    for i in range(N): 
        a = i/10+random.uniform(-1,1)
        yy = math.sin(a)+3+random.uniform(-1,1)
        x.append([a])
        y.append([yy])  
    return np.array(x), np.array(y)

x,y = getData(200)

# %%
#apply linear regression

from sklearn.linear_model import LinearRegression

model = LinearRegression()
print(model)
# Out:
# LinearRegression()

# %%
model.fit(x,y)
pred_y = model.predict(x)

# %%
x_ax=range(200)
plt.scatter(x_ax, y, s=5, color="blue", label="original")
plt.plot(x_ax, pred_y, lw=1.5, color="red", label="predicted")
plt.legend()
plt.show()

# %%
score=model.score(x,y)
print('score = ' ,score)
# Out:
# score =  0.0038837782759886252

# %%
mse =mean_squared_error(y, pred_y)
print("Mean Squared Error:",mse)
# Out:
# Mean Squared Error: 0.772337564880611

# %%
rmse = math.sqrt(mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Root Mean Squared Error: 0.878827380593374

# %%
#apply SVR

from sklearn.svm import SVR 

model = SVR(C = 0.5 , degree = 5)
print(model)
# Out:
# SVR(C=0.5, degree=5)

# %%
model.fit(x,y)
pred_y = model.predict(x)
# Out:
# /Users/khalednada/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
x_ax=range(200)
plt.scatter(x_ax, y, s=5, color="blue", label="original")
plt.plot(x_ax, pred_y, lw=1.5, color="red", label="predicted")
plt.legend()
plt.show()

# %%
score=model.score(x,y)
print('score = ' ,score)
# Out:
# score =  0.07127203690314654

# %%
mse =mean_squared_error(y, pred_y)
print("Mean Squared Error:",mse)
# Out:
# Mean Squared Error: 0.7200881561925712

# %%
rmse = math.sqrt(mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Root Mean Squared Error: 0.8485800823685241
