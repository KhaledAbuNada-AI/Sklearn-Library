# %%
import pandas as pd  
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score ,confusion_matrix

# %%
df = pd.read_csv('Dataset_spine.csv')
df = df.drop(['Unnamed: 13'], axis=1)
df.head()
# Out:
#         Col1       Col2       Col3       Col4        Col5       Col6  \
# 0  63.027818  22.552586  39.609117  40.475232   98.672917  -0.254400
# 1  39.056951  10.060991  25.015378  28.995960  114.405425   4.564259
# 2  68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317
# 3  69.297008  24.652878  44.311238  44.644130  101.868495  11.211523
# 4  49.712859   9.652075  28.317406  40.060784  108.168725   7.918501
#
#        Col7     Col8     Col9     Col10      Col11    Col12 Class_att
# 0  0.744503  12.5661  14.5386  15.30468 -28.658501  43.5123  Abnormal
# 1  0.415186  12.8874  17.5323  16.78486 -25.530607  16.1102  Abnormal
# 2  0.474889  26.8343  17.4861  16.65897 -29.031888  19.2221  Abnormal
# 3  0.369345  23.5603  12.7074  11.42447 -30.470246  18.8329  Abnormal
# 4  0.543360  35.4940  15.9546   8.87237 -16.378376  24.9171  Abnormal

# %%
df.describe()
# Out:
#              Col1        Col2        Col3        Col4        Col5        Col6  \
# count  310.000000  310.000000  310.000000  310.000000  310.000000  310.000000
# mean    60.496653   17.542822   51.930930   42.953831  117.920655   26.296694
# std     17.236520   10.008330   18.554064   13.423102   13.317377   37.559027
# min     26.147921   -6.554948   14.000000   13.366931   70.082575  -11.058179
# 25%     46.430294   10.667069   37.000000   33.347122  110.709196    1.603727
# 50%     58.691038   16.357689   49.562398   42.404912  118.268178   11.767934
# 75%     72.877696   22.120395   63.000000   52.695888  125.467674   41.287352
# max    129.834041   49.431864  125.742385  121.429566  163.071041  418.543082
#
#              Col7        Col8        Col9       Col10       Col11       Col12
# count  310.000000  310.000000  310.000000  310.000000  310.000000  310.000000
# mean     0.472979   21.321526   13.064511   11.933317  -14.053139   25.645981
# std      0.285787    8.639423    3.399713    2.893265   12.225582   10.450558
# min      0.003220    7.027000    7.037800    7.030600  -35.287375    7.007900
# 25%      0.224367   13.054400   10.417800    9.541140  -24.289522   17.189075
# 50%      0.475989   21.907150   12.938450   11.953835  -14.622856   24.931950
# 75%      0.704846   28.954075   15.889525   14.371810   -3.497094   33.979600
# max      0.998827   36.743900   19.324000   16.821080    6.972071   44.341200

# %%
df = df.drop(['Col7','Col8','Col9','Col10','Col11','Col12'], axis=1)
df.head()
# Out:
#         Col1       Col2       Col3       Col4        Col5       Col6 Class_att
# 0  63.027818  22.552586  39.609117  40.475232   98.672917  -0.254400  Abnormal
# 1  39.056951  10.060991  25.015378  28.995960  114.405425   4.564259  Abnormal
# 2  68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317  Abnormal
# 3  69.297008  24.652878  44.311238  44.644130  101.868495  11.211523  Abnormal
# 4  49.712859   9.652075  28.317406  40.060784  108.168725   7.918501  Abnormal

# %%
y = df['Class_att']
x = df.drop(['Class_att'], axis=1)
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.25,random_state=27)

# %%
clf = MLPClassifier(hidden_layer_sizes=(300), activation='relu', solver='adam', max_iter=500, alpha=0.0001, verbose=10,  random_state=21,tol=0.000000001)

# %%
clf.fit(x_train, y_train)
# Out:
# Iteration 1, loss = 1.24605865
# Iteration 2, loss = 0.65091385
# Iteration 3, loss = 0.61847522
# Iteration 4, loss = 0.44142749
# Iteration 5, loss = 0.56171077
# Iteration 6, loss = 0.42819935
# Iteration 7, loss = 0.43435671
# Iteration 8, loss = 0.45936296
# Iteration 9, loss = 0.36137572
# Iteration 10, loss = 0.41470355
# Iteration 11, loss = 0.37158188
# Iteration 12, loss = 0.33231878
# Iteration 13, loss = 0.36686575
# Iteration 14, loss = 0.32147676
# Iteration 15, loss = 0.31701169
# Iteration 16, loss = 0.31238155
# Iteration 17, loss = 0.30560610
# Iteration 18, loss = 0.31567192
# Iteration 19, loss = 0.30434288
# Iteration 20, loss = 0.29865677
# Iteration 21, loss = 0.29708662
# Iteration 22, loss = 0.29648050
# Iteration 23, loss = 0.29739078
# Iteration 24, loss = 0.29403585
# Iteration 25, loss = 0.30047251
# Iteration 26, loss = 0.29330755
# Iteration 27, loss = 0.29923896
# Iteration 28, loss = 0.29265706
# Iteration 29, loss = 0.29759632
# Iteration 30, loss = 0.28823541
# Iteration 31, loss = 0.30446775
# Iteration 32, loss = 0.31416862
# Iteration 33, loss = 0.28839114
# Iteration 34, loss = 0.28900240
# Iteration 35, loss = 0.29267928
# Iteration 36, loss = 0.28936348
# Iteration 37, loss = 0.28528718
# Iteration 38, loss = 0.28603377
# Iteration 39, loss = 0.29145254
# Iteration 40, loss = 0.28948620
# Iteration 41, loss = 0.28585305
# Iteration 42, loss = 0.28736068
# Iteration 43, loss = 0.28887459
# Iteration 44, loss = 0.29034674
# Iteration 45, loss = 0.32945361
# Iteration 46, loss = 0.27832202
# Iteration 47, loss = 0.36544918
# Iteration 48, loss = 0.32562786
# Iteration 49, loss = 0.30580251
# Iteration 50, loss = 0.32015690
# Iteration 51, loss = 0.28595788
# Iteration 52, loss = 0.36842931
# Iteration 53, loss = 0.29956218
# Iteration 54, loss = 0.31565072
# Iteration 55, loss = 0.30441086
# Iteration 56, loss = 0.30167877
# Iteration 57, loss = 0.31218014
# Training loss did not improve more than tol=0.000000 for 10 consecutive epochs. Stopping.
# MLPClassifier(hidden_layer_sizes=300, max_iter=500, random_state=21, tol=1e-09,
#               verbose=10)

# %%
y_pred = clf.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8076923076923077

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[44  9]
#  [ 6 19]]

# %%
sns.heatmap(cm, center=True)
plt.show()

# %%
[[49  4]
 [15 10]]
