# %%
import numpy as np
import pandas as pd

# %%
data_houses = pd.read_csv('houses.csv')

# %%
data_houses.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0       3.0       1.00       1180.0    5650.0     1.0         0.0   0.0
# 1       3.0       2.25       2570.0    7242.0     2.0         0.0   0.0
# 2       2.0       1.00        770.0   10000.0     1.0         0.0   0.0
# 3       4.0       3.00       1960.0    5000.0     1.0         0.0   0.0
# 4       3.0       2.00       1680.0    8080.0     1.0         0.0   0.0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0        3.0    7.0      1180.0            0.0    1955.0           0.0
# 1        3.0    7.0      2170.0          400.0    1951.0        1991.0
# 2        3.0    6.0       770.0            0.0    1933.0           0.0
# 3        5.0    7.0      1050.0          910.0    1965.0           0.0
# 4        3.0    8.0      1680.0            0.0    1987.0           0.0
#
#    zipcode      lat     long  sqft_living15  price
# 0  98178.0  47.5112 -122.257         1340.0  22.19
# ...

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values = np.nan, strategy = 'mean').fit_transform(data_houses)

# %%
X = data_houses.iloc[:, :-1]
y = data_houses.iloc[ :, -1]

# %%
dataset = data_houses.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
print(X)
print('==================================')
print(y)
# Out:
# [[-0.41006301 -1.44922969 -0.98140684 ... -0.27224967 -0.35552515
#   -0.96483545]
#  [-0.41006301  0.28297952  0.58407352 ...  1.21056704 -0.79998899
#   -0.4427495 ]
#  [-1.58385369 -1.44922969 -1.44316723 ...  1.33001224 -0.18347463
#    1.09367489]
#  ...
#  [-1.58385369 -1.44922969 -1.35306765 ...  0.85505856 -0.86450793
#   -1.02450242]
#  [-1.58385369 -1.44922969 -1.15034357 ... -1.24336033  1.07822918
#   -0.8007513 ]
#  [        nan         nan         nan ...         nan         nan
#           nan]]
# ...
# 0      22.190
# 1      53.800
# 2      18.000
# 3      60.400
# 4      51.000
#         ...
# 995    29.100
# 996    19.995
# 997    55.350
# 998    18.995
# 999       NaN
# Name: price, Length: 1000, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=30, random_state=40)

# %%
print(X_train)
print(X_test)
print(y_train)
print(y_test)
# Out:
# [[-0.41006301 -0.06346232 -0.73363297 ... -1.47164908 -0.46305672
#    0.04950298]
#  [-1.58385369 -1.44922969 -1.26296806 ...  1.0416475  -1.17993388
#   -1.39742096]
#  [ 0.76372767  2.01518874  1.98061714 ... -0.25670059  0.05309484
#    1.85442871]
#  ...
#  [-0.41006301 -0.756346   -1.11655622 ... -0.99104119 -0.7713139
#   -0.50241646]
#  [-1.58385369 -0.756346   -0.82373256 ...  1.16462658 -1.14409003
#    0.19867039]
#  [-0.41006301  0.62942137  1.10214615 ...  1.57172974  0.8201534
#    1.63067759]]
# [[-4.10063010e-01 -1.44922969e+00 -1.28549295e+00 -2.16060730e-01
#   -8.64231500e-01 -8.98479487e-02 -3.10078237e-01  7.77066520e-01
#   -1.38396044e+00 -1.06349055e+00 -6.68069570e-01 -2.49429033e-01
#   -2.06868253e-01 -2.94013343e-01 -5.01951975e-01  3.54183244e-01
#   -8.75335004e-01]
#  [-4.10063010e-01 -6.34623195e-02 -8.91307252e-01 -3.14056034e-01
#   -8.64231500e-01 -8.98479487e-02 -3.10078237e-01  7.77066520e-01
# ...

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import LinearRegression

# %%
#clf = linear_model.SGDRegressor( penalty = 'l2' , max_iter=1000, tol=1e-3 , loss = 'huber')
sgd = SGDRegressor( penalty = 'l2' , max_iter=1000, tol=1e-3 , loss = 'squared_loss')
#clf = linear_model.SGDRegressor( penalty = 'l1' , max_iter=1000, tol=1e-3 , loss = 'huber')
#clf = linear_model.SGDRegressor( penalty = 'l1' , max_iter=1000, tol=1e-3 , loss = 'squared_loss')

# %%
# print('Linear Regression Train Score is : ', regressor.score(X_train, y_train))
# print('Linear Regression Test Score is : ' , regressor.score(X_test, y_test))
# print('Linear Regression Coef is : ' , regressor.coef_)
# print('Linear Regression intercept is : ' , regressor.intercept_)
# print('----------------------------------------------------')

# %%
# np.any(np.isnan(data_houses))
# np.all(np.isfinite(data_houses))

# %%
sgd.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-edd4edd82bbe> in <module>
# ----> 1 sgd.fit(X_train, y_train)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py in fit(self, X, y, coef_init, intercept_init, sample_weight)
#    1250         self : returns an instance of self.
#    1251         """
# -> 1252         return self._fit(X, y, alpha=self.alpha, C=1.0,
#    1253                          loss=self.loss, learning_rate=self.learning_rate,
#    1254                          coef_init=coef_init,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py in _fit(self, X, y, alpha, C, loss, learning_rate, coef_init, intercept_init, sample_weight)
#    1212         self.t_ = 1.0
#    1213
# -> 1214         self._partial_fit(X, y, alpha, C, loss, learning_rate,
# ...

# %%
y_pred = sgd.predict(X_test) 
y_pred

# %%
sgd.score(X_train,y_train)
sgd.score(X_test,y_test)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, y_pred)
mean_squared_error(y_test, y_pred)
